# %%
import os
import pandas as pd
import pymongo as pm

# %%
data_path = ['dataset-cefetmg']
filepath = os.sep.join(data_path + ['original-dadospessoais2008a2018_1.csv'])
data = pd.read_csv(filepath, sep=' ', error_bad_lines=False, encoding='latin1')
# Out:
# b'Skipping line 1492: expected 276 fields, saw 279\nSkipping line 1493: expected 276 fields, saw 279\nSkipping line 1494: expected 276 fields, saw 279\nSkipping line 1495: expected 276 fields, saw 279\nSkipping line 1496: expected 276 fields, saw 279\nSkipping line 1497: expected 276 fields, saw 279\nSkipping line 1498: expected 276 fields, saw 279\nSkipping line 1499: expected 276 fields, saw 279\nSkipping line 1500: expected 276 fields, saw 279\nSkipping line 1501: expected 276 fields, saw 279\nSkipping line 1502: expected 276 fields, saw 279\nSkipping line 1503: expected 276 fields, saw 279\nSkipping line 1504: expected 276 fields, saw 279\nSkipping line 1505: expected 276 fields, saw 279\nSkipping line 1506: expected 276 fields, saw 279\nSkipping line 1507: expected 276 fields, saw 279\nSkipping line 1508: expected 276 fields, saw 279\n'
# b'Skipping line 7692: expected 276 fields, saw 278\n'
# ...

# %%
data.head()
# Out:
#    COD_INSTITUICAO  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0                2         NaN         NaN         NaN         NaN
# 1                2         NaN         NaN         NaN         NaN
# 2                2         NaN         NaN         NaN         NaN
# 3                2         NaN         NaN         NaN         NaN
# 4                2         NaN         NaN         NaN         NaN
#
#          DESC_INSTITUICAO  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# 0  Unidade BH - Campus II         NaN         NaN         NaN         NaN
# 1  Unidade BH - Campus II         NaN         NaN         NaN         NaN
# 2  Unidade BH - Campus II         NaN         NaN         NaN         NaN
# 3  Unidade BH - Campus II         NaN         NaN         NaN         NaN
# 4  Unidade BH - Campus II         NaN         NaN         NaN         NaN
#
#    ... Unnamed: 266  Unnamed: 267  Unnamed: 268  Unnamed: 269  \
# ...
