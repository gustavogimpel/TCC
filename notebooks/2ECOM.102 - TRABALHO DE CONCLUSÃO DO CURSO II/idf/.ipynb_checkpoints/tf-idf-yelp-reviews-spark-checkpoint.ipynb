# %%
from __future__ import print_function

import json, codecs, os
import numpy as np
from timeit import default_timer as timer

from pyspark.ml.feature import IDF
from pyspark.ml.feature import Tokenizer
from pyspark.ml.feature import CountVectorizer

from pyspark.sql import SQLContext
from pyspark.sql import SparkSession
from pyspark.sql.functions import col
from pyspark.sql.functions import concat_ws
from pyspark.sql.functions import collect_list

# %%
arr_collections_debug = ["5000000","8000000"]
arr_collections = ["100","500","1000","5000","10000","50000","100000","500000","1000000"]#,"5000000","8000000"]
MONGO_HOST = "192.168.0.15"
MONGO_PORT = "27017"
firstRun = True

review_df = None
spark = SparkSession.builder \
    .appName("tfidf_spark") \
    .master("spark://spark:7077") \
    .config("spark.jars.packages", "org.mongodb.spark:mongo-spark-connector_2.12:3.0.0") \
    .getOrCreate()
spark.sparkContext.setLogLevel('ERROR')
sqlContext = SQLContext(spark)

def getCollectionReadURL(collection):
    return "mongodb://" + MONGO_HOST + ":" + MONGO_PORT + "/yelp_filtered_read." + collection + "?ssl=false"

def readFromCollection(collection, profile=False):
    url = getCollectionReadURL(collection)
    df = spark.read.format("com.mongodb.spark.sql.DefaultSource").option("uri", url).load()
    return df

# %%
def tokenize(review_df):
    tokenizer = Tokenizer(inputCol="text", outputCol="words")
    return tokenizer.transform(review_df)

def vectorize(review_df):
    countVectorizer = CountVectorizer(inputCol='words', outputCol='vectorizer', minDF=3).fit(review_df)
    return countVectorizer.transform(review_df)

def idf(review_df):
    idf = IDF(inputCol="vectorizer", outputCol="tfidf_features").fit(review_df)
    return idf.transform(review_df)

def process(review_df):
    grouped_df = review_df.groupBy("business_id").agg(collect_list('text').alias("text"))
    grouped_df = grouped_df.withColumn("text", concat_ws(" ", col("text")))
    grouped_df = tokenize(grouped_df)
    grouped_df = vectorize(grouped_df)
    grouped_df = idf(grouped_df)
    return grouped_df

# %%
arr_collection_timings = {}
for collection in arr_collections_debug:
    review_df = readFromCollection(collection)
    count = review_df.count()
    arr_timings = []
    
    for i in range(30):
        starttime = timer()
        grouped_df = process(review_df)
        endtime = timer()
        
        if(firstRun):
            print("Ignored: " + str(endtime-starttime))
            firstRun = False
            starttime = timer()
            grouped_df = process(review_df)
            endtime = timer()
        
        arr_timings.append(endtime-starttime)
        print("["+"{:02d}".format(i+1)+"] "+ str(count) + ": " + str(round(endtime-starttime, 3)) + " segundos")
        
    arr_collection_timings[collection] = round(np.mean(arr_timings), 3)
# Out:
# Ignored: 10.537348199999997
# [01] 100: 2.615 segundos
# [02] 100: 2.034 segundos
# [03] 100: 1.665 segundos
# [04] 100: 1.539 segundos
# [05] 100: 1.74 segundos
# [06] 100: 1.44 segundos
# [07] 100: 1.416 segundos
# [08] 100: 1.782 segundos
# [09] 100: 1.303 segundos
# [10] 100: 1.542 segundos
# [11] 100: 1.409 segundos
# [12] 100: 1.223 segundos
# [13] 100: 1.249 segundos
# [14] 100: 1.148 segundos
# [15] 100: 1.247 segundos
# [16] 100: 1.238 segundos
# [17] 100: 1.148 segundos
# [18] 100: 1.197 segundos
# [19] 100: 1.136 segundos
# [20] 100: 1.065 segundos
# [21] 100: 1.106 segundos
# [22] 100: 1.063 segundos
# [23] 100: 1.029 segundos
# [24] 100: 1.112 segundos
# [25] 100: 1.143 segundos
# [26] 100: 1.183 segundos
# [27] 100: 1.052 segundos
# [28] 100: 1.111 segundos
# [29] 100: 1.038 segundos
# [30] 100: 1.125 segundos
# [01] 500: 2.105 segundos
# [02] 500: 1.925 segundos
# [03] 500: 1.781 segundos
# [04] 500: 1.775 segundos
# [05] 500: 1.797 segundos
# [06] 500: 1.875 segundos
# [07] 500: 1.805 segundos
# [08] 500: 1.804 segundos
# [09] 500: 1.827 segundos
# [10] 500: 1.827 segundos
# [11] 500: 1.764 segundos
# [12] 500: 1.787 segundos
# [13] 500: 1.731 segundos
# [14] 500: 1.668 segundos
# [15] 500: 1.688 segundos
# [16] 500: 1.681 segundos
# [17] 500: 1.735 segundos
# [18] 500: 1.762 segundos
# [19] 500: 1.69 segundos
# [20] 500: 1.757 segundos
# [21] 500: 1.729 segundos
# [22] 500: 1.785 segundos
# [23] 500: 1.723 segundos
# [24] 500: 1.684 segundos
# [25] 500: 1.679 segundos
# [26] 500: 1.663 segundos
# [27] 500: 1.64 segundos
# [28] 500: 1.678 segundos
# [29] 500: 1.708 segundos
# [30] 500: 1.742 segundos
# [01] 1000: 2.106 segundos
# [02] 1000: 2.12 segundos
# [03] 1000: 2.131 segundos
# [04] 1000: 2.103 segundos
# [05] 1000: 2.119 segundos
# [06] 1000: 2.105 segundos
# [07] 1000: 2.09 segundos
# [08] 1000: 2.018 segundos
# [09] 1000: 2.081 segundos
# [10] 1000: 2.122 segundos
# [11] 1000: 2.111 segundos
# [12] 1000: 2.023 segundos
# [13] 1000: 2.085 segundos
# [14] 1000: 2.091 segundos
# [15] 1000: 2.05 segundos
# [16] 1000: 2.102 segundos
# [17] 1000: 2.071 segundos
# [18] 1000: 2.075 segundos
# [19] 1000: 2.07 segundos
# [20] 1000: 2.03 segundos
# [21] 1000: 2.054 segundos
# [22] 1000: 2.062 segundos
# [23] 1000: 2.068 segundos
# [24] 1000: 2.013 segundos
# [25] 1000: 2.042 segundos
# [26] 1000: 2.046 segundos
# [27] 1000: 2.052 segundos
# [28] 1000: 2.024 segundos
# [29] 1000: 2.052 segundos
# [30] 1000: 2.037 segundos
# [01] 5000: 3.211 segundos
# [02] 5000: 3.168 segundos
# [03] 5000: 3.121 segundos
# [04] 5000: 3.289 segundos
# [05] 5000: 3.277 segundos
# [06] 5000: 3.363 segundos
# [07] 5000: 3.243 segundos
# [08] 5000: 3.181 segundos
# [09] 5000: 3.17 segundos
# [10] 5000: 3.231 segundos
# [11] 5000: 3.111 segundos
# [12] 5000: 3.241 segundos
# [13] 5000: 3.288 segundos
# [14] 5000: 3.129 segundos
# [15] 5000: 3.21 segundos
# [16] 5000: 3.282 segundos
# [17] 5000: 3.181 segundos
# [18] 5000: 3.109 segundos
# [19] 5000: 3.199 segundos
# [20] 5000: 3.141 segundos
# [21] 5000: 3.227 segundos
# [22] 5000: 3.263 segundos
# [23] 5000: 3.217 segundos
# [24] 5000: 3.112 segundos
# [25] 5000: 3.134 segundos
# [26] 5000: 3.106 segundos
# [27] 5000: 3.103 segundos
# [28] 5000: 3.183 segundos
# [29] 5000: 3.237 segundos
# [30] 5000: 3.218 segundos
# [01] 10000: 4.18 segundos
# [02] 10000: 4.057 segundos
# [03] 10000: 4.068 segundos
# [04] 10000: 4.112 segundos
# [05] 10000: 3.975 segundos
# [06] 10000: 4.236 segundos
# [07] 10000: 4.048 segundos
# [08] 10000: 4.112 segundos
# [09] 10000: 4.045 segundos
# [10] 10000: 4.008 segundos
# [11] 10000: 4.089 segundos
# [12] 10000: 4.221 segundos
# [13] 10000: 4.005 segundos
# [14] 10000: 3.945 segundos
# [15] 10000: 4.134 segundos
# [16] 10000: 4.163 segundos
# [17] 10000: 4.064 segundos
# [18] 10000: 4.135 segundos
# [19] 10000: 4.18 segundos
# [20] 10000: 4.128 segundos
# [21] 10000: 4.043 segundos
# [22] 10000: 4.063 segundos
# [23] 10000: 4.084 segundos
# [24] 10000: 4.066 segundos
# [25] 10000: 4.001 segundos
# [26] 10000: 4.087 segundos
# [27] 10000: 4.099 segundos
# [28] 10000: 4.08 segundos
# [29] 10000: 4.048 segundos
# [30] 10000: 4.168 segundos
# [01] 50000: 9.381 segundos
# [02] 50000: 9.247 segundos
# [03] 50000: 9.546 segundos
# [04] 50000: 9.452 segundos
# [05] 50000: 9.381 segundos
# [06] 50000: 9.383 segundos
# [07] 50000: 9.411 segundos
# [08] 50000: 9.531 segundos
# [09] 50000: 9.268 segundos
# [10] 50000: 9.217 segundos
# [11] 50000: 9.336 segundos
# [12] 50000: 9.293 segundos
# [13] 50000: 9.239 segundos
# [14] 50000: 9.432 segundos
# [15] 50000: 9.128 segundos
# [16] 50000: 9.283 segundos
# [17] 50000: 9.095 segundos
# [18] 50000: 9.232 segundos
# [19] 50000: 9.368 segundos
# [20] 50000: 9.282 segundos
# [21] 50000: 9.086 segundos
# [22] 50000: 9.493 segundos
# [23] 50000: 9.402 segundos
# [24] 50000: 9.434 segundos
# [25] 50000: 9.377 segundos
# [26] 50000: 9.477 segundos
# [27] 50000: 9.295 segundos
# [28] 50000: 9.286 segundos
# [29] 50000: 9.19 segundos
# [30] 50000: 9.351 segundos
# [01] 100000: 15.025 segundos
# [02] 100000: 15.458 segundos
# [03] 100000: 15.396 segundos
# [04] 100000: 14.996 segundos
# [05] 100000: 13.333 segundos
# [06] 100000: 15.166 segundos
# [07] 100000: 13.538 segundos
# [08] 100000: 14.174 segundos
# [09] 100000: 15.333 segundos
# [10] 100000: 15.177 segundos
# [11] 100000: 15.291 segundos
# [12] 100000: 15.1 segundos
# [13] 100000: 15.029 segundos
# [14] 100000: 14.105 segundos
# [15] 100000: 15.32 segundos
# [16] 100000: 15.339 segundos
# [17] 100000: 14.302 segundos
# [18] 100000: 15.278 segundos
# [19] 100000: 13.359 segundos
# [20] 100000: 15.492 segundos
# [21] 100000: 15.063 segundos
# [22] 100000: 15.237 segundos
# [23] 100000: 14.289 segundos
# [24] 100000: 15.224 segundos
# [25] 100000: 14.352 segundos
# [26] 100000: 15.517 segundos
# [27] 100000: 15.418 segundos
# [28] 100000: 15.214 segundos
# [29] 100000: 15.527 segundos
# [30] 100000: 12.635 segundos
# [01] 500000: 47.151 segundos
# [02] 500000: 47.912 segundos
# [03] 500000: 47.746 segundos
# [04] 500000: 47.32 segundos
# [05] 500000: 46.408 segundos
# [06] 500000: 47.059 segundos
# [07] 500000: 46.84 segundos
# [08] 500000: 48.463 segundos
# [09] 500000: 46.938 segundos
# [10] 500000: 47.334 segundos
# [11] 500000: 47.608 segundos
# [12] 500000: 47.739 segundos
# [13] 500000: 48.027 segundos
# [14] 500000: 47.261 segundos
# [15] 500000: 47.057 segundos
# [16] 500000: 47.379 segundos
# [17] 500000: 47.215 segundos
# [18] 500000: 46.558 segundos
# [19] 500000: 47.058 segundos
# [20] 500000: 47.429 segundos
# [21] 500000: 46.993 segundos
# [22] 500000: 48.032 segundos
# [23] 500000: 47.551 segundos
# [24] 500000: 47.974 segundos
# [25] 500000: 48.318 segundos
# [26] 500000: 48.795 segundos
# [27] 500000: 48.932 segundos
# [28] 500000: 49.427 segundos
# [29] 500000: 49.663 segundos
# [30] 500000: 49.273 segundos
# [01] 1000000: 90.947 segundos
# [02] 1000000: 91.48 segundos
# [03] 1000000: 90.745 segundos
# [04] 1000000: 91.115 segundos
# [05] 1000000: 90.966 segundos
# [06] 1000000: 91.82 segundos
# [07] 1000000: 90.981 segundos
# [08] 1000000: 90.189 segundos
# [09] 1000000: 90.613 segundos
# [10] 1000000: 90.716 segundos
# [11] 1000000: 91.231 segundos
# [12] 1000000: 89.637 segundos
# [13] 1000000: 91.912 segundos
# [14] 1000000: 89.947 segundos
# [15] 1000000: 92.274 segundos
# [16] 1000000: 91.924 segundos
# [17] 1000000: 92.218 segundos
# [18] 1000000: 91.92 segundos
# [19] 1000000: 91.633 segundos
# [20] 1000000: 90.344 segundos
# [21] 1000000: 90.745 segundos
# [22] 1000000: 91.341 segundos
# [23] 1000000: 92.605 segundos
# [24] 1000000: 91.537 segundos
# [25] 1000000: 91.185 segundos
# [26] 1000000: 89.331 segundos
# [27] 1000000: 91.148 segundos
# [28] 1000000: 90.456 segundos
# [29] 1000000: 93.484 segundos
# [30] 1000000: 91.597 segundos

# %%
review_df.show()
# Out:
# +--------------------+--------------------+----+-------------------+-----+--------------------+-----+--------------------+------+--------------------+
# |                 _id|         business_id|cool|               date|funny|           review_id|stars|                text|useful|             user_id|
# +--------------------+--------------------+----+-------------------+-----+--------------------+-----+--------------------+------+--------------------+
# |[60120699d445e70d...|-MhfebM0QIsKt87iD...|   0|2015-04-15 05:21:16|    0|xQY8N_XvtGbearJ5X...|    2|As someone who ha...|     5|OwjRMXRC0KyPrIlcj...|
# |[60120699d445e70d...|lbrU8StCq3yDfr-QM...|   0|2013-12-07 03:16:52|    1|UmFMZ8PyXZTY2Qcwz...|    1|I am actually hor...|     1|nIJD_7ZXHq-FX8byP...|
# |[60120699d445e70d...|HQl28KMwrEKHqhFrr...|   0|2015-12-05 03:18:11|    0|LG2ZaYiOgpr2DK_90...|    5|I love Deagan's. ...|     1|V34qejxNsCbcgD8C0...|
# |[60120699d445e70d...|5JxlZaqCnk1MnbgRi...|   0|2011-05-27 05:30:52|    0|i6g_oA9Yf9Y31qt0w...|    1|Dismal, lukewarm,...|     0|ofKDkJKXSKZXu5xJN...|
# |[60120699d445e70d...|IS4cv902ykd8wj1TR...|   0|2017-01-14 21:56:57|    0|6TdNDKywdbjoTkize...|    4|Oh happy day, fin...|     0|UgMW8bLE0QMJDCkQ1...|
# |[60120699d445e70d...|nlxHRv1zXGT0c0K51...|   0|2013-05-07 07:25:25|    0|L2O_INwlrRuoX05KS...|    5|This is definitel...|     2|5vD2kmE25YBrbayKh...|
# |[60120699d445e70d...|Pthe4qk5xh4n-ef-9...|   0|2015-11-05 23:11:05|    0|ZayJ1zWyWgY9S_TRL...|    5|Really good place...|     1|aq_ZxGHiri48TUXJl...|
# |[60120699d445e70d...|FNCJpSn0tL9iqoY3J...|   0|2017-07-18 18:31:54|    0|lpFIJYpsvDxyph-kP...|    5|Awesome office an...|     0|dsd-KNYKMpx6ma_sR...|
# |[60120699d445e70d...|e_BiI4ej1CW1F0EyV...|   0|2015-02-16 06:48:47|    0|JA-xnyHytKiOIHl_z...|    5|Most delicious au...|     0|P6apihD4ASf1vpPxH...|
# |[60120699d445e70d...|Ws8V970-mQt2X9CwC...|   1|2009-10-13 04:16:41|    0|z4BCgTkfNtCu4XY5L...|    4|I have been here ...|     3|jOERvhmK6_lo_XGUB...|
# |[60120699d445e70d...|PA61Rwk3AMwOEXHev...|   0|2013-12-28 21:02:55|    0|TfVth7UNfgilv4J3e...|    5|Maria is VERY goo...|     0|s5j_CRBWDCCMDJ6r7...|
# |[60120699d445e70d...|l-nL4BmhzpZjcavoo...|   1|2015-10-17 01:38:13|    1|Tyx7AxYQfSRnBFUIX...|    4|ORDER In (Deliver...|     2|HJECayULRM-6xh2GC...|
# |[60120699d445e70d...|Naa6E0YU0Wr7jCuCE...|   0|2015-07-03 21:48:51|    0|wJMjt5C2y1RKgY0Xb...|    5|We purchased new ...|     3|1YIQGP-a534nyksaw...|
# |[60120699d445e70d...|Ns4tjgLfqR1qawGlN...|   0|2016-06-11 22:00:11|    0|QCxPzh7cuxJrLd6A_...|    5|Everything that m...|     0|qftVgPj_kRTildMDj...|
# |[60120699d445e70d...|ZlCSsWS07JulSBIQl...|   0|2015-05-26 10:36:47|    0|qWHp2l2lysENZObh6...|    5|Called for a 5:15...|     1|5lb0POg2t-AkMFx66...|
# |[60120699d445e70d...|7Ka9Pd8X9SRHs1D5E...|   0|2017-08-07 21:36:36|    0|mjbs5CL4eMu4o6_Vt...|    1|If I could give l...|     0|TF4C-F5iqavACQgKT...|
# |[60120699d445e70d...|d4qwVw4PcN-_2mK2o...|   0|2015-02-02 06:28:00|    0|bVTjZgRNq8Toxzvti...|    1|10pm on a super b...|     0|2hRe26HSCAWbFRn5W...|
# |[60120699d445e70d...|oVuZtlCFg_zF090Nh...|   1|2018-02-01 19:15:00|    0|Ne_2CSfcKIqXHmv_K...|    4|A close friend wa...|     3|6sJN_HlM_uwpfLJ1p...|
# |[60120699d445e70d...|_iGvLfEsqDwPUxRUA...|   0|2017-06-28 00:39:18|    0|Hy-gUXQh3RVhE8FLH...|    1|Tried to have my ...|     0|kMkWON2lmw0s-M-fw...|
# |[60120699d445e70d...|poSV39UqEg-gpESXa...|   0|2018-03-04 01:03:53|    0|UGErdm6bt48SXTVwJ...|    3|My husband and I ...|     0|QodunSzok4nIYFNrT...|
# +--------------------+--------------------+----+-------------------+-----+--------------------+-----+--------------------+------+--------------------+
# only showing top 20 rows

# %%
# Bellagio Gallery of Fine Art
#company_df1 = review_df[review_df['business_id'] == "-MhfebM0QIsKt87iDN-FNw"]

#The Empanadas House
#company_df2 = review_df[review_df['business_id'] == "pQeaRpvuhoEqudo3uymHIQ"]

# %%
#company_df1.select("vectorizer").collect()

# %%
#company_df2.select("vectorizer").collect()

# %%
arr_collection_timings
# Out:
# {'100': 1.337,
#  '500': 1.76,
#  '1000': 2.072,
#  '5000': 3.198,
#  '10000': 4.088,
#  '50000': 9.33,
#  '100000': 14.823,
#  '500000': 47.715,
#  '1000000': 91.201}
