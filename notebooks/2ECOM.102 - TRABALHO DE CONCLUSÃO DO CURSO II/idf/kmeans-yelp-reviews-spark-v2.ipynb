# %%
from __future__ import print_function

import os
import json
import codecs
import numpy as np
import pandas as pd
import textblob as tb
import cProfile, pstats, sys
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

from pyspark import SparkContext
from pyspark.ml.clustering import KMeans
from pyspark.ml.feature import IDF
from pyspark.ml.feature import Tokenizer
from pyspark.ml.feature import HashingTF
from pyspark.ml.feature import CountVectorizer
from pyspark.ml.feature import VectorAssembler

from pyspark.sql import SparkSession
from pyspark.sql import SQLContext

# %matplotlib inline

# %%
MONGO_URL_INPUT = "mongodb://192.168.0.15:27017/yelp.review?ssl=false"
MONGO_URL_OUTPUT = "mongodb://192.168.0.15:27017/yelp.teste"

review_df = None
profiler = cProfile.Profile()
spark = SparkSession.builder \
    .appName("kmeans-spark") \
    .master("spark://spark:7077") \
    .config("spark.mongodb.input.uri", MONGO_URL_INPUT) \
    .config("spark.mongodb.output.uri", MONGO_URL_OUTPUT) \
    .config('spark.jars.packages', 'org.mongodb.spark:mongo-spark-connector_2.12:3.0.0')\
    .getOrCreate()
sqlContext = SQLContext(spark)

def profile():
    profiler.disable()
    ps = pstats.Stats(profiler, stream=sys.stdout)
    ps.print_stats()

# %%
def readDataset():
    return spark.read.format("com.mongodb.spark.sql.DefaultSource").load()

def tokenize(review_df):
    tokenizer = Tokenizer(inputCol="text", outputCol="words")
    return tokenizer.transform(review_df)

def vectorize(review_df):
    vectorizer = CountVectorizer(inputCol='words', outputCol='vectorizer').fit(review_df)
    return vectorizer.transform(review_df)

def idf(review_df):
    idf = IDF(inputCol="vectorizer", outputCol="tfidf_features")
    idf_model = idf.fit(review_df)
    return idf_model.transform(review_df)

def polarity(text):
    blob = tb.TextBlob(text)
    return blob.sentiment.polarity

def subjectivity(text):
    blob = tb.TextBlob(text)
    return blob.sentiment.subjectivity

def get_pol_sub():
    review_df['polarity'] = review_df['text'].apply(polarity)
    review_df['subjectivity'] = review_df['text'].apply(subjectivity)
    
    print('\nMean Polarity: ' + str(review_df['polarity'].mean())\
          + '\nMean Subjectivity: ' + str(review_df['subjectivity'].mean()))

# %%
# A tokenizer that converts the input string to lowercase and then splits it by white spaces.
profiler.enable()

review_df = readDataset()
review_df = review_df[review_df['business_id'] == 'HQl28KMwrEKHqhFrrDqVNQ']

review_df = tokenize(review_df)
review_df = vectorize(review_df)
review_df = idf(review_df)

profile()
# Out:
#          22424 function calls (22048 primitive calls) in 84.054 seconds
#
#    Random listing order was used
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 {method 'get' of 'mappingproxy' objects}
#       247    0.002    0.000   84.021    0.340 {method 'readline' of '_io.BufferedReader' objects}
#       247    0.000    0.000    0.000    0.000 {method '_checkClosed' of '_io._IOBase' objects}
#       247    0.000    0.000    0.000    0.000 {method '_checkReadable' of '_io._IOBase' objects}
#       247    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#       247    0.000    0.000    0.000    0.000 {method 'pop' of 'collections.deque' objects}
#         5    0.000    0.000    0.000    0.000 {built-in method posix.urandom}
#         6    0.000    0.000    0.000    0.000 {built-in method builtins.compile}
#        10    0.001    0.000    0.001    0.000 {built-in method builtins.dir}
#         6    0.000    0.000   84.054   14.009 {built-in method builtins.exec}
#      1561    0.001    0.000    0.034    0.000 {built-in method builtins.getattr}
#        48    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#       174    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
# 4540/4436    0.001    0.000    0.002    0.000 {built-in method builtins.isinstance}
#    136/50    0.000    0.000    0.001    0.000 {built-in method builtins.issubclass}
#   552/528    0.000    0.000    0.002    0.000 {built-in method builtins.len}
#        12    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         6    0.000    0.000    0.000    0.000 {built-in method builtins.repr}
#        22    0.000    0.000    0.000    0.000 {built-in method builtins.setattr}
#       247    0.000    0.000    0.000    0.000 {method 'encode' of 'str' objects}
#       144    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#        39    0.000    0.000    0.000    0.000 {method 'split' of 'str' objects}
#   160/136    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#        17    0.000    0.000    0.000    0.000 {method 'lower' of 'str' objects}
#       247    0.000    0.000    0.000    0.000 {method 'strip' of 'str' objects}
#       429    0.000    0.000    0.000    0.000 {method 'startswith' of 'str' objects}
#       494    0.000    0.000    0.000    0.000 {method 'format' of 'str' objects}
#        36    0.000    0.000    0.000    0.000 {method '__subclasses__' of 'type' objects}
#        32    0.000    0.000    0.000    0.000 {method '__reduce_ex__' of 'object' objects}
#        32    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x55a7f2582a80}
#        56    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#        28    0.000    0.000    0.000    0.000 {method 'remove' of 'set' objects}
#        64    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#        71    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#        16    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#        32    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#         5    0.000    0.000    0.000    0.000 {built-in method from_bytes}
#       125    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         5    0.000    0.000    0.000    0.000 {method 'count' of 'list' objects}
#         4    0.000    0.000    0.000    0.000 {method 'is_integer' of 'float' objects}
#        38    0.000    0.000    0.000    0.000 {built-in method sys._getframe}
#         1    0.000    0.000   63.790   63.790 <ipython-input-4-f764664e2804>:8(vectorize)
#         1    0.000    0.000   11.610   11.610 <ipython-input-4-f764664e2804>:12(idf)
#         1    0.000    0.000    0.022    0.022 /opt/conda/lib/python3.6/site-packages/pyspark/ml/feature.py:4034(__init__)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pyspark/ml/feature.py:4044(setParams)
#         2    0.000    0.000    0.001    0.001 /opt/conda/lib/python3.6/site-packages/pyspark/ml/feature.py:665(__init__)
#         1    0.000    0.000    0.013    0.013 /opt/conda/lib/python3.6/site-packages/pyspark/ml/feature.py:761(__init__)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pyspark/ml/feature.py:774(setParams)
#         1    0.000    0.000    0.006    0.006 /opt/conda/lib/python3.6/site-packages/pyspark/ml/feature.py:833(_create_model)
#         2    0.000    0.000    0.001    0.001 /opt/conda/lib/python3.6/site-packages/pyspark/ml/feature.py:1305(__init__)
#         1    0.000    0.000    0.009    0.009 /opt/conda/lib/python3.6/site-packages/pyspark/ml/feature.py:1362(__init__)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pyspark/ml/feature.py:1372(setParams)
#         1    0.000    0.000    0.003    0.003 /opt/conda/lib/python3.6/site-packages/pyspark/ml/feature.py:1401(_create_model)
#         5    0.000    0.000    0.002    0.000 /opt/conda/lib/python3.6/site-packages/pyspark/ml/wrapper.py:37(__init__)
#         5    0.000    0.000    0.001    0.000 /opt/conda/lib/python3.6/site-packages/pyspark/ml/wrapper.py:41(__del__)
#         3    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pyspark/ml/wrapper.py:68(<listcomp>)
#         3    0.000    0.000    0.043    0.014 /opt/conda/lib/python3.6/site-packages/pyspark/ml/wrapper.py:59(_new_java_obj)
#        27    0.000    0.000    0.022    0.001 /opt/conda/lib/python3.6/site-packages/pyspark/ml/wrapper.py:125(_make_java_param_pair)
#         5    0.000    0.000    0.050    0.010 /opt/conda/lib/python3.6/site-packages/pyspark/ml/wrapper.py:135(_transfer_params_to_java)
#         2    0.000    0.000    0.007    0.004 /opt/conda/lib/python3.6/site-packages/pyspark/ml/wrapper.py:163(_create_params_from_java)
#         2    0.000    0.000   75.087   37.544 /opt/conda/lib/python3.6/site-packages/pyspark/ml/wrapper.py:308(_fit_java)
#         2    0.000    0.000   75.097   37.548 /opt/conda/lib/python3.6/site-packages/pyspark/ml/wrapper.py:320(_fit)
#         3    0.000    0.000    0.450    0.150 /opt/conda/lib/python3.6/site-packages/pyspark/ml/wrapper.py:336(_transform)
#         2    0.000    0.000    0.009    0.005 /opt/conda/lib/python3.6/site-packages/pyspark/ml/wrapper.py:351(__init__)
#         5    0.000    0.000    0.002    0.000 /opt/conda/lib/python3.6/site-packages/pyspark/ml/param/shared.py:154(__init__)
#        70    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pyspark/ml/common.py:42(_new_smart_decode)
#        30    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pyspark/ml/common.py:70(_py2java)
#         5    0.000    0.000    0.002    0.000 /opt/conda/lib/python3.6/site-packages/pyspark/ml/param/shared.py:188(__init__)
#         3    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pyspark/ml/util.py:36(_jvm)
#         5    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pyspark/ml/util.py:53(__init__)
#         5    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pyspark/ml/util.py:60(_randomUID)
#         2    0.000    0.000   75.097   37.548 /opt/conda/lib/python3.6/site-packages/pyspark/ml/base.py:107(fit)
#         3    0.000    0.000    0.450    0.150 /opt/conda/lib/python3.6/site-packages/pyspark/ml/base.py:155(transform)
#        22    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pyspark/ml/param/__init__.py:52(_copy_new_parent)
#       174    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pyspark/ml/param/__init__.py:61(__str__)
#       174    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pyspark/ml/param/__init__.py:67(__hash__)
#        24    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pyspark/ml/param/__init__.py:70(__eq__)
#        10    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pyspark/ml/param/__init__.py:84(_is_numeric)
#         4    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pyspark/ml/param/__init__.py:89(_is_integer)
#         6    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pyspark/ml/param/__init__.py:189(toFloat)
#         4    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pyspark/ml/param/__init__.py:199(toInt)
#        15    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pyspark/ml/param/__init__.py:209(toString)
#         2    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pyspark/ml/param/__init__.py:223(toBoolean)
#         5    0.000    0.000    0.002    0.000 /opt/conda/lib/python3.6/site-packages/pyspark/ml/param/__init__.py:244(__init__)
#         5    0.000    0.000    0.001    0.000 /opt/conda/lib/python3.6/site-packages/pyspark/ml/param/__init__.py:263(<listcomp>)
#       426    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pyspark/ml/param/__init__.py:264(<lambda>)
#         5    0.000    0.000    0.002    0.000 /opt/conda/lib/python3.6/site-packages/pyspark/ml/param/__init__.py:258(_copy_params)
#       445    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pyspark/ml/param/__init__.py:276(<lambda>)
#         5    0.000    0.000    0.001    0.000 /opt/conda/lib/python3.6/site-packages/pyspark/ml/param/__init__.py:277(<listcomp>)
#         9    0.000    0.000    0.001    0.000 /opt/conda/lib/python3.6/site-packages/pyspark/ml/param/__init__.py:268(params)
#         8    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pyspark/ml/param/__init__.py:305(getParam)
#        22    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pyspark/ml/param/__init__.py:315(isSet)
#        22    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pyspark/ml/param/__init__.py:322(hasDefault)
#        83    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pyspark/ml/param/__init__.py:336(hasParam)
#        71    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pyspark/ml/param/__init__.py:406(_shouldOwn)
#        71    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pyspark/ml/param/__init__.py:413(_resolveParam)
#         7    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pyspark/ml/param/__init__.py:445(_set)
#         9    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pyspark/ml/param/__init__.py:466(_setDefault)
#         2    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pyspark/ml/param/__init__.py:481(_copyValues)
#         2    0.000    0.000    0.001    0.000 /opt/conda/lib/python3.6/site-packages/pyspark/ml/param/__init__.py:510(_resetUid)
#         1    0.000    0.000    0.012    0.012 /opt/conda/lib/python3.6/site-packages/pyspark/sql/readwriter.py:57(__init__)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pyspark/sql/readwriter.py:61(_df)
#         1    0.000    0.000    0.007    0.007 /opt/conda/lib/python3.6/site-packages/pyspark/sql/readwriter.py:65(format)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pyspark/sql/readwriter.py:127(options)
#         1    0.000    0.000    8.278    8.278 /opt/conda/lib/python3.6/site-packages/pyspark/sql/readwriter.py:152(load)
#       124    0.000    0.000    0.002    0.000 /opt/conda/lib/python3.6/site-packages/pyspark/sql/utils.py:126(deco)
#         1    0.000    0.000    0.012    0.012 /opt/conda/lib/python3.6/site-packages/pyspark/sql/session.py:664(read)
#         5    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pyspark/sql/dataframe.py:77(__init__)
#         2    0.000    0.000    0.053    0.026 /opt/conda/lib/python3.6/site-packages/pyspark/sql/dataframe.py:1365(__getitem__)
#         1    0.000    0.000    0.024    0.024 /opt/conda/lib/python3.6/site-packages/pyspark/sql/dataframe.py:1438(filter)
#         1    0.000    0.000    0.111    0.111 /opt/conda/lib/python3.6/site-packages/pyspark/sql/column.py:116(_)
#         2    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pyspark/sql/column.py:154(__init__)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pyspark/sql/context.py:94(_ssql_ctx)
#        60    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pyspark/sql/types.py:1624(can_convert)
#        60    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pyspark/sql/types.py:1633(can_convert)
#         2    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/py4j/java_collections.py:162(__init__)
#        12    0.000    0.000    0.002    0.000 /opt/conda/lib/python3.6/site-packages/py4j/java_collections.py:165(__compute_index)
#        12    0.000    0.000    0.004    0.000 /opt/conda/lib/python3.6/site-packages/py4j/java_collections.py:176(__compute_item)
#        12    0.000    0.000    0.004    0.000 /opt/conda/lib/python3.6/site-packages/py4j/java_collections.py:196(__getitem__)
#        14    0.000    0.000    0.002    0.000 /opt/conda/lib/python3.6/site-packages/py4j/java_collections.py:243(__len__)
#         5    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/py4j/java_collections.py:261(__init__)
#        65    0.000    0.000    0.001    0.000 /opt/conda/lib/python3.6/site-packages/py4j/java_collections.py:489(can_convert)
#        65    0.000    0.000    0.001    0.000 /opt/conda/lib/python3.6/site-packages/py4j/java_collections.py:501(can_convert)
#         5    0.000    0.000    0.005    0.001 /opt/conda/lib/python3.6/site-packages/py4j/java_collections.py:507(convert)
#        65    0.000    0.000    0.001    0.000 /opt/conda/lib/python3.6/site-packages/py4j/java_collections.py:516(can_convert)
#         5    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/py4j/java_collections.py:535(<lambda>)
#         2    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/py4j/java_collections.py:538(<lambda>)
#        17    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/py4j/protocol.py:161(<lambda>)
#        14    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/py4j/protocol.py:164(<lambda>)
#        12    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/py4j/protocol.py:167(<lambda>)
#        48    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/py4j/protocol.py:177(escape_new_line)
#        24    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/py4j/protocol.py:206(<genexpr>)
#        12    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/py4j/protocol.py:193(unescape_new_line)
#       669    0.001    0.000    0.001    0.000 /opt/conda/lib/python3.6/site-packages/py4j/protocol.py:214(smart_decode)
#         6    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/py4j/protocol.py:224(encode_float)
#        43    0.000    0.000    0.007    0.000 /opt/conda/lib/python3.6/site-packages/py4j/protocol.py:248(is_python_proxy)
#       113    0.000    0.000    0.007    0.000 /opt/conda/lib/python3.6/site-packages/py4j/protocol.py:263(get_command_part)
#       148    0.000    0.000    0.002    0.000 /opt/conda/lib/python3.6/site-packages/py4j/protocol.py:305(get_return_value)
#       148    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/py4j/protocol.py:373(is_error)
#       247    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/py4j/protocol.py:380(is_fatal_error)
#         5    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/py4j/java_gateway.py:425(get_method)
#       144    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/py4j/compat.py:92(ispython3bytestr)
#       144    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/py4j/compat.py:95(isbytearray)
#       130    0.000    0.000    0.002    0.000 /opt/conda/lib/python3.6/site-packages/py4j/compat.py:113(hasattr2)
#       174    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/py4j/java_gateway.py:632(is_magic_member)
#        71    0.000    0.000    0.010    0.000 /opt/conda/lib/python3.6/site-packages/py4j/java_gateway.py:638(_garbage_collect_object)
#        71    0.000    0.000    0.010    0.000 /opt/conda/lib/python3.6/site-packages/py4j/java_gateway.py:956(garbage_collect_object)
#       247    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/py4j/java_gateway.py:973(_get_connection)
#       247    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/py4j/java_gateway.py:988(_give_back_connection)
#       247    0.001    0.000   84.037    0.340 /opt/conda/lib/python3.6/site-packages/py4j/java_gateway.py:1010(send_command)
#       247    0.002    0.000   84.036    0.340 /opt/conda/lib/python3.6/site-packages/py4j/java_gateway.py:1178(send_command)
#       123    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/py4j/java_gateway.py:1221(__init__)
#    116/99    0.000    0.000    0.009    0.000 /opt/conda/lib/python3.6/site-packages/py4j/java_gateway.py:1240(_get_args)
#       116    0.000    0.000    0.007    0.000 /opt/conda/lib/python3.6/site-packages/py4j/java_gateway.py:1266(<listcomp>)
#    116/99    0.000    0.000    0.016    0.000 /opt/conda/lib/python3.6/site-packages/py4j/java_gateway.py:1258(_build_args)
#    116/99    0.001    0.000   83.993    0.848 /opt/conda/lib/python3.6/site-packages/py4j/java_gateway.py:1295(__call__)
#        61    0.000    0.000    0.008    0.000 /opt/conda/lib/python3.6/site-packages/py4j/java_gateway.py:1340(<lambda>)
#       105    0.001    0.000    0.001    0.000 /opt/conda/lib/python3.6/site-packages/py4j/java_gateway.py:1317(__init__)
#        10    0.000    0.000    0.002    0.000 /opt/conda/lib/python3.6/site-packages/py4j/java_gateway.py:1345(_detach)
#        67    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/py4j/java_gateway.py:1348(_get_object_id)
#       154    0.000    0.000    0.001    0.000 /opt/conda/lib/python3.6/site-packages/py4j/java_gateway.py:1360(__getattr__)
#        13    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/py4j/java_gateway.py:1456(__init__)
#         5    0.000    0.000    0.001    0.000 /opt/conda/lib/python3.6/site-packages/py4j/java_gateway.py:1506(__getattr__)
#         8    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/py4j/java_gateway.py:1533(_get_args)
#         8    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/py4j/java_gateway.py:1560(<listcomp>)
#         8    0.000    0.000    0.010    0.001 /opt/conda/lib/python3.6/site-packages/py4j/java_gateway.py:1551(__call__)
#        15    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/py4j/java_gateway.py:1610(__init__)
#        15    0.000    0.000    0.029    0.002 /opt/conda/lib/python3.6/site-packages/py4j/java_gateway.py:1620(__getattr__)
#         8    0.000    0.000    0.009    0.001 /opt/conda/lib/python3.6/site-packages/py4j/java_gateway.py:1688(__getattr__)
#         5    0.000    0.000    0.001    0.000 /opt/conda/lib/python3.6/site-packages/py4j/java_gateway.py:2047(detach)
#        98    0.000    0.000    0.001    0.000 /opt/conda/lib/python3.6/site-packages/py4j/java_gateway.py:2525(<lambda>)
#       105    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/py4j/finalizer.py:35(add_finalizer)
#        71    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/py4j/finalizer.py:45(remove_finalizer)
#         1    0.000    0.000    0.164    0.164 <ipython-input-5-2773e44bdddd>:5(<module>)
#       6/3    0.000    0.000    0.045    0.015 /opt/conda/lib/python3.6/site-packages/pyspark/__init__.py:105(wrapper)
#         1    0.000    0.000   63.790   63.790 <ipython-input-5-2773e44bdddd>:8(<module>)
#         1    0.000    0.000    0.192    0.192 <ipython-input-5-2773e44bdddd>:7(<module>)
#         1    0.000    0.000    8.298    8.298 <ipython-input-5-2773e44bdddd>:4(<module>)
#         1    0.000    0.000    8.298    8.298 <ipython-input-4-f764664e2804>:1(readDataset)
#         1    0.000    0.000   11.610   11.610 <ipython-input-5-2773e44bdddd>:9(<module>)
#         1    0.000    0.000    0.000    0.000 <ipython-input-5-2773e44bdddd>:11(<module>)
#         1    0.000    0.000    0.000    0.000 <ipython-input-2-5c643829edf3>:15(profile)
#         1    0.000    0.000    0.192    0.192 <ipython-input-4-f764664e2804>:4(tokenize)
#         5    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/uuid.py:106(__init__)
#         5    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/uuid.py:280(hex)
#         5    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/uuid.py:621(uuid4)
#       247   84.018    0.340   84.018    0.340 {method 'recv_into' of '_socket.socket' objects}
#       247    0.010    0.000    0.010    0.000 {method 'sendall' of '_socket.socket' objects}
#       247    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/socket.py:611(readable)
#       247    0.001    0.000   84.019    0.340 /opt/conda/lib/python3.6/socket.py:572(readinto)
#         6    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/IPython/core/hooks.py:103(__call__)
#         6    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/IPython/core/hooks.py:168(pre_run_code_hook)
#         6    0.000    0.000   84.054   14.009 /opt/conda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3302(run_code)
#         6    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3244(compare)
#         6    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:1276(user_global_ns)
#         8    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/typing.py:875(__extrahook__)
#         4    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/typing.py:889(__extrahook__)
#        30    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/typing.py:1019(_abc_negative_cache)
#        18    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/typing.py:1033(_abc_negative_cache_version)
#        24    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/typing.py:1089(__eq__)
#     56/18    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/typing.py:1145(__subclasscheck__)
#         5    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:117(<lambda>)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         6    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/codeop.py:132(__call__)
#         6    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/IPython/utils/ipstruct.py:125(__getattr__)
#       601    0.001    0.000    0.001    0.000 /opt/conda/lib/python3.6/inspect.py:1512(_static_getmro)
#       130    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/inspect.py:1515(_check_instance)
#       130    0.000    0.000    0.001    0.000 /opt/conda/lib/python3.6/inspect.py:1524(_check_class)
#       130    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/inspect.py:1533(_is_type)
#       341    0.001    0.000    0.001    0.000 /opt/conda/lib/python3.6/inspect.py:1540(_shadowed_dict)
#       130    0.000    0.000    0.002    0.000 /opt/conda/lib/python3.6/inspect.py:1554(getattr_static)
#         6    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/traitlets/traitlets.py:526(get)
#         6    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/traitlets/traitlets.py:545(__get__)
#       494    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/logging/__init__.py:1530(getEffectiveLevel)
#       494    0.001    0.000    0.001    0.000 /opt/conda/lib/python3.6/logging/__init__.py:1544(isEnabledFor)
#        12    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/IPython/core/compilerop.py:138(extra_flags)
#        32    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/copy.py:268(_reconstruct)
#       494    0.000    0.000    0.001    0.000 /opt/conda/lib/python3.6/logging/__init__.py:1286(debug)
#        32    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/copy.py:66(copy)
#        32    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/copyreg.py:87(__newobj__)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/copyreg.py:96(_slotnames)
#         6    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/contextlib.py:79(__enter__)
#         6    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/contextlib.py:85(__exit__)
#         6    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/contextlib.py:157(helper)
#         6    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/contextlib.py:59(__init__)
#        24    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/_collections_abc.py:392(__subclasshook__)
#        12    0.000    0.000    0.004    0.000 /opt/conda/lib/python3.6/_collections_abc.py:879(__iter__)
#        65    0.000    0.000    0.001    0.000 /opt/conda/lib/python3.6/abc.py:180(__instancecheck__)
#      48/2    0.000    0.000    0.001    0.000 /opt/conda/lib/python3.6/abc.py:196(__subclasscheck__)
#        28    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/_weakrefset.py:16(__init__)
#        28    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/_weakrefset.py:20(__enter__)
#        28    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/_weakrefset.py:26(__exit__)
#        28    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/_weakrefset.py:52(_commit_removals)
#        44    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/_weakrefset.py:58(__iter__)
#       226    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/_weakrefset.py:70(__contains__)
#        28    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/_weakrefset.py:81(add)
#         3    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:997(_handle_fromlist)

# %%
kmeans = KMeans().setK(3).setFeaturesCol("tfidf_features")
model = kmeans.fit(review_df)
predictions = model.transform(review_df)

# %%
review_df.count()
# Out:
# 453
