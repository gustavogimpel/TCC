# %% [markdown]
# ## Motivation for this Notebook
#
# If I was a business owner, I would want to know how my customers are generally feeling. After reading a couple of reviews, you can start to pick up on some trends but who has the time to go through all of the comments to get a full picture of what people are saying about the company? Well luckily we have the power of NLP and Machine Learning algorithms that can do this compiling and grouping for us. Here I try to get a better look into 'average' reviews for a particular business and what's being said in them by implementing kMeans clustering.

# %%
import numpy as np
import pandas as pd 
import seaborn as sns
import cProfile, pstats, sys
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.stem.snowball import SnowballStemmer
from nltk.tokenize import RegexpTokenizer
from nltk.tokenize import word_tokenize
from sklearn.cluster import KMeans
import textblob as tb

# %%
review_df = None
profiler = cProfile.Profile()
snowball = SnowballStemmer('english')
tokenizer = RegexpTokenizer(r'[a-zA-Z\']+')

def profile():
    profiler.disable()
    ps = pstats.Stats(profiler, stream=sys.stdout)
    ps.print_stats()
    
def readDataset():
    #return pd.read_json('yelp_academic_dataset_review.json', lines = True)
    return pd.read_json('filtered.json')

def tokenize(text):
    return [snowball.stem(word) for word in tokenizer.tokenize(text.lower())]

def vectorize(review_df):
    vectorizer = TfidfVectorizer(stop_words = 'english', tokenizer = tokenize, \
                    min_df = 0.0025, max_df = 0.05, max_features = 1000, ngram_range = (1, 3))
    return vectorizer.fit_transform(review_df['text'])

# %%
profiler.enable()

review_df = readDataset()
#review_df = review_df[review_df['business_id'] == 'HQl28KMwrEKHqhFrrDqVNQ']

X = vectorize(review_df)

profile()
# Out:
# /opt/conda/lib/python3.6/site-packages/sklearn/feature_extraction/text.py:300: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['abov', 'afterward', 'alon', 'alreadi', 'alway', 'ani', 'anoth', 'anyon', 'anyth', 'anywher', 'becam', 'becaus', 'becom', 'befor', 'besid', 'cri', 'describ', 'dure', 'els', 'elsewher', 'empti', 'everi', 'everyon', 'everyth', 'everywher', 'fifti', 'forti', 'henc', 'hereaft', 'herebi', 'howev', 'hundr', 'inde', 'mani', 'meanwhil', 'moreov', 'nobodi', 'noon', 'noth', 'nowher', 'onc', 'onli', 'otherwis', 'ourselv', 'perhap', 'pleas', 'sever', 'sinc', 'sincer', 'sixti', 'someon', 'someth', 'sometim', 'somewher', 'themselv', 'thenc', 'thereaft', 'therebi', 'therefor', 'togeth', 'twelv', 'twenti', 'veri', 'whatev', 'whenc', 'whenev', 'wherea', 'whereaft', 'wherebi', 'wherev', 'whi', 'yourselv'] not in stop_words.
#   'stop_words.' % sorted(inconsistent))
#          4297478 function calls (4294039 primitive calls) in 1.450 seconds
#
#    Random listing order was used
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#        16    0.000    0.000    0.000    0.000 {method 'read' of '_io.StringIO' objects}
#         2    0.004    0.002    0.004    0.002 {method 'read' of '_io.TextIOWrapper' objects}
#         2    0.001    0.000    0.001    0.000 {method 'close' of '_io.TextIOWrapper' objects}
#         1    0.000    0.000    0.000    0.000 {method 'readline' of '_io.BufferedReader' objects}
#         1    0.000    0.000    0.000    0.000 {method 'seek' of '_io.BufferedReader' objects}
#         2    0.001    0.000    0.001    0.000 {method 'read' of '_io.FileIO' objects}
#         1    0.001    0.001    0.001    0.001 {method 'readlines' of '_io._IOBase' objects}
#         3    0.001    0.000    0.001    0.000 {built-in method io.open}
#        12    0.000    0.000    0.000    0.000 {built-in method _locale.setlocale}
#         2    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#        17    0.000    0.000    0.000    0.000 {built-in method _operator.index}
#         2    0.000    0.000    0.000    0.000 {built-in method _operator.gt}
#         1    0.000    0.000    0.000    0.000 {built-in method _codecs.lookup}
#        12    0.000    0.000    0.000    0.000 {built-in method _codecs.utf_8_decode}
#        81    0.000    0.000    0.000    0.000 {method 'match' of '_sre.SRE_Pattern' objects}
#        68    0.000    0.000    0.000    0.000 {method 'search' of '_sre.SRE_Pattern' objects}
#         6    0.000    0.000    0.000    0.000 {method 'sub' of '_sre.SRE_Pattern' objects}
#       771    0.011    0.000    0.011    0.000 {method 'findall' of '_sre.SRE_Pattern' objects}
#         1    0.000    0.000    0.000    0.000 {method 'group' of '_sre.SRE_Match' objects}
#         8    0.000    0.000    0.000    0.000 {built-in method _sre.compile}
#       143    0.000    0.000    0.000    0.000 {built-in method _sre.getlower}
#        39    0.002    0.000    0.002    0.000 {built-in method posix.stat}
#         5    0.000    0.000    0.000    0.000 {built-in method posix.getcwd}
#         2    0.003    0.001    0.003    0.001 {built-in method posix.listdir}
#         1    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#        14    0.000    0.000    0.000    0.000 {built-in method posix.fspath}
#         2    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#        14    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#        14    0.000    0.000    0.000    0.000 {built-in method _thread.get_ident}
#         2    0.000    0.000    0.000    0.000 {built-in method marshal.loads}
#        50    0.000    0.000    0.000    0.000 {built-in method _imp.acquire_lock}
#        50    0.000    0.000    0.000    0.000 {built-in method _imp.release_lock}
#         5    0.000    0.000    0.000    0.000 {built-in method _imp.is_builtin}
#         7    0.000    0.000    0.000    0.000 {built-in method _imp.is_frozen}
#         2    0.000    0.000    0.000    0.000 {built-in method _imp._fix_co_filename}
#        78    0.000    0.000    0.000    0.000 {built-in method builtins.all}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.any}
#        32    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.compile}
#       7/5    0.000    0.000    1.450    0.290 {built-in method builtins.exec}
#      4552    0.002    0.000    0.002    0.000 {built-in method builtins.getattr}
#      1081    0.000    0.000    0.001    0.000 {built-in method builtins.hasattr}
#       268    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.id}
# 11639/11457    0.003    0.000    0.006    0.000 {built-in method builtins.isinstance}
# 3513/2097    0.001    0.000    0.005    0.000 {built-in method builtins.issubclass}
# 289426/289098    0.022    0.000    0.022    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.locals}
#        40    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#       584    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#        10    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#       146    0.000    0.000    0.000    0.000 {built-in method builtins.ord}
#        59    0.000    0.000    0.000    0.000 {built-in method builtins.setattr}
#         2    0.043    0.022    0.043    0.022 {built-in method builtins.sorted}
#         6    0.000    0.000    0.000    0.000 {built-in method builtins.sum}
#         3    0.000    0.000    0.002    0.001 {built-in method _warnings.warn}
#        12    0.000    0.000    0.000    0.000 {built-in method _warnings._filters_mutated}
#    190645    0.028    0.000    0.028    0.000 {method 'replace' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'split' of 'str' objects}
#     64416    0.010    0.000    0.010    0.000 {method 'join' of 'str' objects}
#         6    0.000    0.000    0.000    0.000 {method 'index' of 'str' objects}
#     60772    0.008    0.000    0.008    0.000 {method 'lower' of 'str' objects}
#       328    0.000    0.000    0.000    0.000 {method 'rstrip' of 'str' objects}
#        58    0.000    0.000    0.000    0.000 {method 'rpartition' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'strip' of 'str' objects}
#        18    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#    143333    0.020    0.000    0.020    0.000 {method 'startswith' of 'str' objects}
#   3267180    0.368    0.000    0.368    0.000 {method 'endswith' of 'str' objects}
#         4    0.000    0.000    0.000    0.000 {method 'isspace' of 'str' objects}
#         4    0.000    0.000    0.000    0.000 {method 'isdigit' of 'str' objects}
#        12    0.000    0.000    0.000    0.000 {method 'isalpha' of 'str' objects}
#         6    0.000    0.000    0.000    0.000 {method 'isidentifier' of 'str' objects}
#        33    0.000    0.000    0.000    0.000 {method 'format' of 'str' objects}
#       208    0.000    0.000    0.000    0.000 {method '__subclasses__' of 'type' objects}
#        13    0.000    0.000    0.000    0.000 {method '__subclasshook__' of 'object' objects}
#        50    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x55f063360a80}
#     51883    0.005    0.000    0.005    0.000 {method 'add' of 'set' objects}
#       176    0.000    0.000    0.000    0.000 {method 'remove' of 'set' objects}
#       117    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#      1363    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#        15    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#       453    0.000    0.000    0.000    0.000 {method 'values' of 'dict' objects}
#         6    0.000    0.000    0.000    0.000 {method 'clear' of 'dict' objects}
#         3    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#         4    0.000    0.000    0.000    0.000 {built-in method from_bytes}
#     56762    0.005    0.000    0.005    0.000 {method 'append' of 'list' objects}
#         4    0.000    0.000    0.000    0.000 {method 'insert' of 'list' objects}
#       473    0.001    0.000    0.001    0.000 {method 'extend' of 'list' objects}
#         4    0.000    0.000    0.000    0.000 {method 'remove' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'decode' of 'bytes' objects}
#         1    0.000    0.000    0.000    0.000 {method 'startswith' of 'bytes' objects}
#        33    0.000    0.000    0.000    0.000 {method 'find' of 'bytearray' objects}
#         2    0.000    0.000    0.000    0.000 {method 'translate' of 'bytearray' objects}
#      1106    0.000    0.000    0.000    0.000 {built-in method sys._getframe}
#         1    0.000    0.000    0.000    0.000 <ipython-input-11-1a6aabf9fdd7>:8(<module>)
#         1    0.002    0.002    1.385    1.385 <ipython-input-13-0bf43247abac>:6(<module>)
#         1    0.000    0.000    1.383    1.383 <ipython-input-10-6ca6227bbaa4>:18(vectorize)
#         1    0.000    0.000    0.001    0.001 /opt/conda/lib/python3.6/site-packages/pandas/core/computation/expressions.py:7(<module>)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/computation/check.py:1(<module>)
#       771    0.023    0.000    1.162    0.002 <ipython-input-10-6ca6227bbaa4>:16(<listcomp>)
#       771    0.001    0.000    1.176    0.002 <ipython-input-10-6ca6227bbaa4>:15(tokenize)
#         2    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/computation/expressions.py:217(evaluate)
#         2    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/computation/expressions.py:195(_bool_arith_check)
#         2    0.000    0.000    0.000    0.000 <ipython-input-10-6ca6227bbaa4>:6(profile)
#         2    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/computation/expressions.py:186(_has_bool_dtype)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/computation/expressions.py:39(set_use_numexpr)
#         2    0.000    0.000    0.065    0.032 <ipython-input-10-6ca6227bbaa4>:11(readDataset)
#         2    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/computation/expressions.py:61(_evaluate_standard)
#         1    0.000    0.000    0.040    0.040 <ipython-input-11-1a6aabf9fdd7>:3(<module>)
#         1    0.000    0.000    0.000    0.000 <ipython-input-13-0bf43247abac>:8(<module>)
#         1    0.000    0.000    0.024    0.024 <ipython-input-13-0bf43247abac>:3(<module>)
#     59105    0.631    0.000    1.139    0.000 /opt/conda/lib/python3.6/site-packages/nltk/stem/snowball.py:1402(stem)
#       937    0.000    0.000    0.001    0.000 /opt/conda/lib/python3.6/site-packages/nltk/stem/util.py:9(suffix_replace)
#     47641    0.063    0.000    0.070    0.000 /opt/conda/lib/python3.6/site-packages/nltk/stem/snowball.py:227(_r1r2_standard)
#       771    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/nltk/tokenize/regexp.py:118(_check_regexp)
#       771    0.001    0.000    0.012    0.000 /opt/conda/lib/python3.6/site-packages/nltk/tokenize/regexp.py:122(tokenize)
#         1    0.001    0.001    0.001    0.001 {sklearn.utils.sparsefuncs_fast.inplace_csr_row_normalize_l2}
#         1    0.000    0.000    0.001    0.001 /opt/conda/lib/python3.6/site-packages/sklearn/preprocessing/data.py:1553(normalize)
#         3    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/sklearn/utils/extmath.py:663(_safe_accumulator_op)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/sklearn/utils/fixes.py:189(_astype_copy_false)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/sklearn/feature_extraction/text.py:106(_check_stop_list)
#       453    0.001    0.000    0.001    0.000 /opt/conda/lib/python3.6/site-packages/sklearn/feature_extraction/text.py:122(decode)
#       453    0.005    0.000    0.005    0.000 /opt/conda/lib/python3.6/site-packages/sklearn/feature_extraction/text.py:152(<listcomp>)
#       453    0.020    0.000    0.037    0.000 /opt/conda/lib/python3.6/site-packages/sklearn/feature_extraction/text.py:148(_word_ngrams)
#       771    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/sklearn/feature_extraction/text.py:240(<lambda>)
#       771    0.000    0.000    0.001    0.000 /opt/conda/lib/python3.6/site-packages/sklearn/feature_extraction/text.py:256(<lambda>)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/sklearn/feature_extraction/text.py:230(build_preprocessor)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/sklearn/feature_extraction/text.py:260(build_tokenizer)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/sklearn/feature_extraction/text.py:267(get_stop_words)
#         1    0.000    0.000    0.010    0.010 /opt/conda/lib/python3.6/site-packages/sklearn/feature_extraction/text.py:271(_check_stop_words_consistency)
#       453    0.002    0.000    1.208    0.003 /opt/conda/lib/python3.6/site-packages/sklearn/feature_extraction/text.py:351(<lambda>)
#         1    0.000    0.000    0.010    0.010 /opt/conda/lib/python3.6/site-packages/sklearn/feature_extraction/text.py:330(build_analyzer)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/sklearn/feature_extraction/text.py:358(_validate_vocabulary)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/sklearn/feature_extraction/text.py:394(_validate_params)
#         2    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/sklearn/feature_extraction/text.py:680(_document_frequency)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/sklearn/feature_extraction/text.py:864(__init__)
#         1    0.018    0.018    0.062    0.062 /opt/conda/lib/python3.6/site-packages/sklearn/feature_extraction/text.py:897(_sort_features)
#         1    0.028    0.028    0.037    0.037 /opt/conda/lib/python3.6/site-packages/sklearn/feature_extraction/text.py:911(_limit_features)
#         1    0.033    0.033    1.277    1.277 /opt/conda/lib/python3.6/site-packages/sklearn/feature_extraction/text.py:952(_count_vocab)
#         1    0.005    0.005    1.380    1.380 /opt/conda/lib/python3.6/site-packages/sklearn/feature_extraction/text.py:1027(fit_transform)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/sklearn/feature_extraction/text.py:1161(_make_int_array)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/sklearn/feature_extraction/text.py:1247(__init__)
#         1    0.000    0.000    0.001    0.001 /opt/conda/lib/python3.6/site-packages/sklearn/feature_extraction/text.py:1254(fit)
#         1    0.000    0.000    0.002    0.002 /opt/conda/lib/python3.6/site-packages/sklearn/feature_extraction/text.py:1286(transform)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/sklearn/feature_extraction/text.py:1540(__init__)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/sklearn/feature_extraction/text.py:1611(_check_params)
#         1    0.000    0.000    1.383    1.383 /opt/conda/lib/python3.6/site-packages/sklearn/feature_extraction/text.py:1635(fit_transform)
#         3    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/sklearn/utils/validation.py:131(_num_samples)
#         3    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/sklearn/utils/validation.py:234(_ensure_sparse_format)
#         3    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/sklearn/utils/validation.py:325(_ensure_no_complex_data)
#         3    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/sklearn/utils/validation.py:332(check_array)
#         3    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/sklearn/utils/validation.py:581(_check_large_sparse)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/sklearn/utils/validation.py:913(<listcomp>)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/sklearn/utils/validation.py:866(check_is_fitted)
#         3    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/sklearn/_config.py:13(get_config)
#        10    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/IPython/utils/shimmodule.py:31(find_module)
#         3    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/sklearn/utils/validation.py:36(_assert_all_finite)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/scipy/sparse/construct.py:165(<listcomp>)
#         1    0.000    0.000    0.001    0.001 /opt/conda/lib/python3.6/site-packages/scipy/sparse/construct.py:65(diags)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/scipy/sparse/compressed.py:1099(__get_sorted)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/scipy/sparse/compressed.py:1114(__set_sorted)
#         1    0.000    0.000    0.015    0.015 /opt/conda/lib/python3.6/site-packages/scipy/sparse/compressed.py:1130(sort_indices)
#         6    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/scipy/sparse/compressed.py:1139(prune)
#        30    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/scipy/sparse/data.py:25(_get_dtype)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/scipy/sparse/dia.py:78(__init__)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/scipy/sparse/dia.py:348(tocoo)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/scipy/sparse/dia.py:397(isspmatrix_dia)
#         1    0.000    0.000    0.001    0.001 /opt/conda/lib/python3.6/site-packages/scipy/sparse/_index.py:19(__getitem__)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/scipy/sparse/_index.py:114(_validate_indices)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/scipy/sparse/_index.py:138(_asindices)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/scipy/sparse/_index.py:233(_unpack_index)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/scipy/sparse/_index.py:272(_check_ellipsis)
#         3    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/scipy/sparse/csc.py:232(_swap)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/scipy/sparse/coo.py:128(__init__)
#         4    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/scipy/sparse/coo.py:241(getnnz)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/scipy/sparse/coo.py:267(_check)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/scipy/sparse/coo.py:374(tocsr)
#         1    0.000    0.000    0.000    0.000 {built-in method scipy.sparse._sparsetools.csr_matmat_pass1}
#         1    0.000    0.000    0.000    0.000 {built-in method scipy.sparse._sparsetools.csr_matmat_pass2}
#         1    0.015    0.015    0.015    0.015 {built-in method scipy.sparse._sparsetools.csr_sort_indices}
#         1    0.000    0.000    0.000    0.000 {built-in method scipy.sparse._sparsetools.csr_column_index1}
#         1    0.000    0.000    0.000    0.000 {built-in method scipy.sparse._sparsetools.csr_column_index2}
#         1    0.000    0.000    0.000    0.000 {built-in method scipy.sparse._sparsetools.csr_has_sorted_indices}
#         1    0.001    0.001    0.001    0.001 {built-in method scipy.sparse._sparsetools.csc_matvec}
#         1    0.000    0.000    0.000    0.000 {built-in method scipy.sparse._sparsetools.coo_tocsr}
#         2    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/scipy/sparse/base.py:298(asformat)
#         2    0.000    0.000    0.002    0.001 /opt/conda/lib/python3.6/site-packages/scipy/sparse/base.py:454(__mul__)
#         1    0.000    0.000    0.001    0.001 /opt/conda/lib/python3.6/site-packages/scipy/sparse/base.py:542(__rmul__)
#         8    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/scipy/sparse/base.py:674(__getattr__)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/scipy/sparse/base.py:885(tocsr)
#         1    0.000    0.000    0.002    0.002 /opt/conda/lib/python3.6/site-packages/scipy/sparse/base.py:952(sum)
#        17    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/scipy/sparse/base.py:1189(isspmatrix)
#         3    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/scipy/sparse/sputils.py:21(upcast)
#         7    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/scipy/sparse/sputils.py:92(to_native)
#        17    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/scipy/sparse/sputils.py:120(get_index_dtype)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/scipy/sparse/sputils.py:173(get_sum_dtype)
#         5    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/scipy/sparse/sputils.py:182(isscalarlike)
#         7    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/scipy/sparse/sputils.py:209(isshape)
#         3    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/scipy/sparse/sputils.py:239(isdense)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/scipy/sparse/sputils.py:243(validateaxis)
#        24    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/scipy/sparse/sputils.py:279(<genexpr>)
#         4    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/scipy/sparse/sputils.py:187(isintlike)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/scipy/sparse/sputils.py:55(upcast_char)
#         8    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/scipy/sparse/sputils.py:266(check_shape)
#         2    0.000    0.000    0.001    0.000 /opt/conda/lib/python3.6/site-packages/scipy/sparse/sputils.py:352(asmatrix)
#        19    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/scipy/sparse/csr.py:228(_swap)
#         1    0.000    0.000    0.001    0.001 /opt/conda/lib/python3.6/site-packages/scipy/sparse/csr.py:315(_get_sliceXarray)
#         2    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/scipy/sparse/csr.py:328(isspmatrix_csr)
#         8    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/scipy/sparse/data.py:22(__init__)
#         6    0.000    0.000    0.001    0.000 /opt/conda/lib/python3.6/site-packages/scipy/sparse/compressed.py:30(__init__)
#        24    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/scipy/sparse/compressed.py:110(getnnz)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/scipy/sparse/compressed.py:127(_set_self)
#         6    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/scipy/sparse/compressed.py:138(check_format)
#         1    0.000    0.000    0.001    0.001 /opt/conda/lib/python3.6/site-packages/scipy/sparse/compressed.py:464(_mul_vector)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/scipy/sparse/compressed.py:491(_mul_sparse_matrix)
#         1    0.000    0.000    0.002    0.002 /opt/conda/lib/python3.6/site-packages/scipy/sparse/compressed.py:586(sum)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/scipy/sparse/compressed.py:701(_major_slice)
#         1    0.000    0.000    0.001    0.001 /opt/conda/lib/python3.6/site-packages/scipy/sparse/compressed.py:733(_minor_index_fancy)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/scipy/sparse/csr.py:128(transpose)
#         8    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/scipy/sparse/base.py:70(__init__)
#        55    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/scipy/sparse/base.py:84(get_shape)
#        28    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/scipy/sparse/base.py:242(nnz)
#         2    0.000    0.000    0.065    0.032 /opt/conda/lib/python3.6/site-packages/pandas/io/json/_json.py:347(read_json)
#         2    0.000    0.000    0.011    0.005 /opt/conda/lib/python3.6/site-packages/pandas/io/json/_json.py:634(__init__)
#         2    0.000    0.000    0.004    0.002 /opt/conda/lib/python3.6/site-packages/pandas/io/json/_json.py:682(_preprocess_data)
#         2    0.000    0.000    0.006    0.003 /opt/conda/lib/python3.6/site-packages/pandas/io/json/_json.py:697(_get_data_from_filepath)
#         2    0.000    0.000    0.054    0.027 /opt/conda/lib/python3.6/site-packages/pandas/io/json/_json.py:739(read)
#         2    0.000    0.000    0.053    0.027 /opt/conda/lib/python3.6/site-packages/pandas/io/json/_json.py:759(_get_object_parser)
#         2    0.000    0.000    0.001    0.000 /opt/conda/lib/python3.6/site-packages/pandas/io/json/_json.py:786(close)
#         2    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/io/json/_json.py:830(__init__)
#         2    0.000    0.000    0.053    0.027 /opt/conda/lib/python3.6/site-packages/pandas/io/json/_json.py:878(parse)
#         2    0.000    0.000    0.016    0.008 /opt/conda/lib/python3.6/site-packages/pandas/io/json/_json.py:895(_convert_axes)
#        24    0.000    0.000    0.020    0.001 /opt/conda/lib/python3.6/site-packages/pandas/io/json/_json.py:912(_try_convert_data)
#         6    0.000    0.000    0.021    0.004 /opt/conda/lib/python3.6/site-packages/pandas/io/json/_json.py:985(_try_convert_to_date)
#         2    0.000    0.000    0.017    0.009 /opt/conda/lib/python3.6/site-packages/pandas/io/json/_json.py:1112(_parse_no_numpy)
#        20    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/io/json/_json.py:1146(<lambda>)
#         4    0.000    0.000    0.020    0.005 /opt/conda/lib/python3.6/site-packages/pandas/io/json/_json.py:1141(_process_converter)
#        20    0.000    0.000    0.004    0.000 /opt/conda/lib/python3.6/site-packages/pandas/io/json/_json.py:1172(<lambda>)
#         2    0.000    0.000    0.020    0.010 /opt/conda/lib/python3.6/site-packages/pandas/io/json/_json.py:1165(_try_convert_types)
#        20    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/io/json/_json.py:1185(is_ok)
#         2    0.000    0.000    0.006    0.003 /opt/conda/lib/python3.6/site-packages/pandas/io/json/_json.py:1205(<lambda>)
#        20    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/io/json/_json.py:1206(<lambda>)
#         2    0.000    0.000    0.011    0.006 /opt/conda/lib/python3.6/site-packages/pandas/io/json/_json.py:1175(_try_convert_dates)
#         2    0.007    0.003    0.007    0.003 {built-in method pandas._libs.json.loads}
#         4    0.000    0.000    0.005    0.001 /opt/conda/lib/python3.6/site-packages/pandas/core/internals/construction.py:237(init_dict)
#         6    0.000    0.000    0.002    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals/construction.py:329(_homogenize)
#         2    0.000    0.000    0.005    0.003 /opt/conda/lib/python3.6/site-packages/pandas/core/internals/construction.py:498(to_arrays)
#       908    0.001    0.000    0.001    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals/construction.py:637(<genexpr>)
#         4    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals/construction.py:638(<genexpr>)
#         2    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals/construction.py:643(<listcomp>)
#         2    0.000    0.000    0.005    0.003 /opt/conda/lib/python3.6/site-packages/pandas/core/internals/construction.py:609(_list_of_dict_to_arrays)
#         4    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals/construction.py:683(<genexpr>)
#         2    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals/construction.py:651(_validate_or_indexify_columns)
#        20    0.000    0.000    0.002    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals/construction.py:726(convert)
#         2    0.000    0.000    0.002    0.001 /opt/conda/lib/python3.6/site-packages/pandas/core/internals/construction.py:732(<listcomp>)
#         2    0.000    0.000    0.002    0.001 /opt/conda/lib/python3.6/site-packages/pandas/core/internals/construction.py:709(_convert_object_array)
#        44    0.000    0.000    0.004    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/frame.py:953(items)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/frame.py:2869(__getitem__)
#        41    0.000    0.000    0.001    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/frame.py:3184(_box_col_values)
#         6    0.000    0.000    0.006    0.001 /opt/conda/lib/python3.6/site-packages/pandas/core/internals/construction.py:60(arrays_to_mgr)
#         4    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals/construction.py:274(<listcomp>)
#         4    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals/construction.py:278(<listcomp>)
#         4    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals/construction.py:281(<listcomp>)
#         6    0.000    0.000    0.016    0.003 /opt/conda/lib/python3.6/site-packages/pandas/core/frame.py:441(__init__)
#        16    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/tools/datetimes.py:79(should_cache)
#        16    0.000    0.000    0.005    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/tools/datetimes.py:259(_convert_listlike_datetimes)
#        16    0.000    0.000    0.018    0.001 /opt/conda/lib/python3.6/site-packages/pandas/core/tools/datetimes.py:605(to_datetime)
#        18    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals/managers.py:1689(<genexpr>)
#         6    0.000    0.000    0.005    0.001 /opt/conda/lib/python3.6/site-packages/pandas/core/internals/managers.py:1684(create_block_manager_from_arrays)
#         6    0.000    0.000    0.005    0.001 /opt/conda/lib/python3.6/site-packages/pandas/core/internals/managers.py:1724(form_blocks)
#        10    0.000    0.000    0.001    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals/managers.py:1821(_simple_blockify)
#        24    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals/managers.py:1839(<lambda>)
#         6    0.000    0.000    0.001    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals/managers.py:1836(_multi_blockify)
#        60    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals/managers.py:1855(_asarray_compat)
#        16    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals/managers.py:1861(_shape_compat)
#        16    0.000    0.000    0.001    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals/managers.py:1852(_stack_arrays)
#         8    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/io/common.py:67(_expand_user)
#         6    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/io/common.py:97(stringify_path)
#         2    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/io/common.py:140(is_fsspec_url)
#         2    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/io/common.py:152(get_filepath_or_buffer)
#         2    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/io/common.py:269(get_compression_method)
#         4    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/io/common.py:302(infer_compression)
#         2    0.000    0.000    0.006    0.003 /opt/conda/lib/python3.6/site-packages/pandas/io/common.py:356(get_handle)
#         6    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals/managers.py:138(<listcomp>)
#         6    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals/blocks.py:2008(_holder)
#         4    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals/blocks.py:2025(internal_values)
#         6    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals/blocks.py:2029(array_values)
#         2    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals/blocks.py:2032(iget)
#         8    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals/blocks.py:2048(__init__)
#         8    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals/blocks.py:2056(_maybe_coerce_values)
#         2    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/io/common.py:49(is_url)
#        45    0.000    0.000    0.001    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals/blocks.py:2396(__init__)
#        94    0.000    0.000    0.003    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals/blocks.py:2677(get_block_type)
#        34    0.000    0.000    0.002    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals/blocks.py:2723(make_block)
#         8    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals/blocks.py:2750(_extend_blocks)
#         6    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals/managers.py:132(__init__)
#        41    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals/managers.py:163(blknos)
#        41    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals/managers.py:179(blklocs)
#        48    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals/managers.py:214(<genexpr>)
#        16    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals/managers.py:212(shape)
#        16    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals/managers.py:216(ndim)
#         6    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals/managers.py:220(set_axis)
#         5    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals/managers.py:238(_rebuild_blknos_and_blklocs)
#        64    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals/managers.py:259(items)
#        58    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals/managers.py:309(__len__)
#        22    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals/managers.py:326(<genexpr>)
#         6    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals/managers.py:324(_verify_integrity)
#        30    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals/managers.py:388(<dictcomp>)
#        30    0.000    0.000    0.003    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals/managers.py:369(apply)
#        30    0.000    0.000    0.003    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals/managers.py:601(astype)
#         6    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals/managers.py:684(is_consolidated)
#         6    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals/managers.py:693(<listcomp>)
#         6    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals/managers.py:692(_consolidate_check)
#         6    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals/managers.py:986(_consolidate_inplace)
#        41    0.000    0.000    0.001    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals/managers.py:993(iget)
#        67    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals/managers.py:1541(__init__)
#         8    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals/managers.py:1562(from_blocks)
#        18    0.000    0.000    0.001    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals/managers.py:1573(from_array)
#       407    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals/managers.py:1584(_block)
#       316    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals/managers.py:1611(dtype)
#        91    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals/managers.py:1622(internal_values)
#        16    0.000    0.000    0.011    0.001 /opt/conda/lib/python3.6/site-packages/pandas/core/tools/datetimes.py:135(_maybe_cache)
#        83    0.000    0.000    0.001    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals/blocks.py:124(__init__)
#        83    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals/blocks.py:135(_check_ndim)
#        87    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals/blocks.py:201(internal_values)
#        22    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals/blocks.py:213(get_values)
#       120    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals/blocks.py:233(mgr_locs)
#        83    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals/blocks.py:237(mgr_locs)
#        49    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals/blocks.py:256(make_block_same_class)
#        18    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals/blocks.py:311(shape)
#       362    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals/blocks.py:315(dtype)
#        39    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals/blocks.py:319(iget)
#        30    0.000    0.000    0.003    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals/blocks.py:514(astype)
#         8    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/internals/blocks.py:675(copy)
#        89    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/generic.py:195(__init__)
#         8    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/generic.py:232(attrs)
#        32    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/generic.py:249(_validate_dtype)
#         4    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/generic.py:365(_get_axis_number)
#         4    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/generic.py:377(_get_axis)
#         6    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/generic.py:562(_set_axis)
#        41    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/generic.py:3180(_set_as_cached)
#         6    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/generic.py:3250(_clear_item_cache)
#        41    0.000    0.000    0.003    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/generic.py:3534(_get_item_cache)
#         8    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/generic.py:5097(__finalize__)
#        83    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/generic.py:5125(__getattr__)
#       171    0.000    0.000    0.001    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/generic.py:5143(__setattr__)
#        30    0.000    0.000    0.004    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/generic.py:5395(astype)
#         2    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/indexes/range.py:86(__new__)
#         2    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/indexes/range.py:116(from_range)
#         4    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/indexes/range.py:134(_simple_new)
#         6    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/indexes/range.py:153(_data)
#         2    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/indexes/range.py:214(start)
#         2    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/indexes/range.py:237(stop)
#         2    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/indexes/range.py:260(step)
#        24    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/indexes/range.py:320(dtype)
#         2    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/indexes/range.py:404(copy)
#       106    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/indexes/range.py:687(__len__)
#     83/67    0.001    0.000    0.012    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/series.py:201(__init__)
#        16    0.000    0.000    0.007    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/series.py:335(_init_dict)
#        10    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/series.py:381(_constructor)
#        75    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/series.py:398(_set_axis)
#       316    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/series.py:427(dtype)
#        93    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/series.py:442(name)
#        91    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/series.py:492(name)
#        91    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/series.py:540(_values)
#        58    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/series.py:595(__len__)
#         2    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/indexes/extension.py:53(fget)
#         2    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/indexes/extension.py:77(method)
#         2    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/indexes/datetimes.py:231(tz_localize)
#         2    0.000    0.000    0.001    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/indexes/datetimes.py:246(__new__)
#         6    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/indexes/datetimes.py:285(_simple_new)
#         4    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/indexes/numeric.py:50(__new__)
#        10    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/indexes/numeric.py:81(_validate_dtype)
#        43    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/indexes/numeric.py:150(is_all_dates)
#        68    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/arrays/sparse/dtype.py:187(construct_from_string)
#        41    0.000    0.000    0.000    0.000 {method 'get_loc' of 'pandas._libs.index.IndexEngine' objects}
#         2    0.000    0.000    0.002    0.001 /opt/conda/lib/python3.6/site-packages/pandas/core/indexes/base.py:120(cmp_method)
#         8    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/indexes/base.py:424(<genexpr>)
#     64/22    0.001    0.000    0.006    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/indexes/base.py:293(__new__)
#        22    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/indexes/base.py:463(_simple_new)
#         6    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/indexes/base.py:520(is_)
#        32    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/indexes/base.py:544(_reset_identity)
#         2    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/indexes/base.py:561(<lambda>)
#         2    0.001    0.000    0.001    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/indexes/base.py:554(_engine)
#        98    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/indexes/base.py:567(__len__)
#         2    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/indexes/base.py:590(dtype)
#         8    0.000    0.000    0.001    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/indexes/base.py:625(astype)
#        14    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/indexes/base.py:1175(name)
#        10    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/indexes/base.py:1182(name)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/indexes/base.py:1378(nlevels)
#         2    0.001    0.000    0.001    0.001 /opt/conda/lib/python3.6/site-packages/pandas/core/indexes/base.py:1646(is_unique)
#        41    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/indexes/base.py:1755(is_floating)
#         2    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/indexes/base.py:2000(inferred_type)
#        16    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/indexes/base.py:2007(is_all_dates)
#        41    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/indexes/base.py:2854(get_loc)
#        54    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/indexes/base.py:3873(_values)
#         2    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/pandas/core/indexes/base.py:3899(_get_engine_target)
# ...
#         2    0.000    0.000    0.000    0.000 <string>:12(__new__)
#        12    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/locale.py:379(normalize)
#        12    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/locale.py:462(_parse_localename)
#        12    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/locale.py:565(getlocale)
#         5    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/six.py:184(find_module)
#         5    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/traitlets/traitlets.py:526(get)
#         5    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/traitlets/traitlets.py:545(__get__)
#        30    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/inspect.py:73(isclass)
#        10    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/site-packages/IPython/core/compilerop.py:138(extra_flags)
#         2    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/threading.py:1062(_wait_for_tstate_lock)
#         2    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/threading.py:506(is_set)
#         2    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/threading.py:1104(is_alive)
#         1    0.000    0.000    0.001    0.001 /opt/conda/lib/python3.6/linecache.py:15(getline)
#         1    0.000    0.000    0.001    0.001 /opt/conda/lib/python3.6/linecache.py:37(getlines)
#         1    0.000    0.000    0.001    0.001 /opt/conda/lib/python3.6/linecache.py:82(updatecache)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/tokenize.py:344(_get_normal_name)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/tokenize.py:379(read_or_stop)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/tokenize.py:385(find_cookie)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/tokenize.py:355(detect_encoding)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/tokenize.py:448(open)
#         5    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/sre_compile.py:388(_simple)
#       4/3    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/sre_compile.py:414(_get_literal_prefix)
#         3    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/sre_compile.py:441(_get_charset_prefix)
#         8    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/sre_compile.py:482(_compile_info)
#        16    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/sre_compile.py:539(isstring)
#         8    0.000    0.000    0.002    0.000 /opt/conda/lib/python3.6/sre_compile.py:542(_code)
#         8    0.000    0.000    0.003    0.000 /opt/conda/lib/python3.6/sre_compile.py:557(compile)
#         8    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/sre_parse.py:76(__init__)
#        30    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/sre_parse.py:81(groups)
#         7    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/sre_parse.py:84(opengroup)
#         7    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/sre_parse.py:96(closegroup)
#        47    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/sre_parse.py:111(__init__)
#        25    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/sre_parse.py:159(__len__)
#       164    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/sre_parse.py:163(__getitem__)
#         5    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/sre_parse.py:167(__setitem__)
#       153    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/sre_parse.py:171(append)
#     59/20    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/sre_parse.py:173(getwidth)
#         8    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/sre_parse.py:223(__init__)
#       259    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/sre_parse.py:232(__next)
#        89    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/sre_parse.py:248(match)
#       191    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/sre_parse.py:253(get)
#         6    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/sre_parse.py:266(getuntil)
#        32    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/sre_parse.py:285(tell)
#         6    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/sre_parse.py:294(_class_escape)
#        14    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/sre_parse.py:342(_escape)
#      15/8    0.000    0.000    0.001    0.000 /opt/conda/lib/python3.6/sre_parse.py:407(_parse_sub)
#      39/8    0.000    0.000    0.001    0.000 /opt/conda/lib/python3.6/sre_parse.py:470(_parse)
#         8    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/sre_parse.py:828(fix_flags)
#         8    0.000    0.000    0.001    0.000 /opt/conda/lib/python3.6/sre_parse.py:844(parse)
#        14    0.000    0.000    0.004    0.000 /opt/conda/lib/python3.6/re.py:231(compile)
#        14    0.000    0.000    0.004    0.000 /opt/conda/lib/python3.6/re.py:286(_compile)
#         6    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/re.py:324(_subx)
#       828    0.000    0.000    0.001    0.000 /opt/conda/lib/python3.6/enum.py:267(__call__)
#        21    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/sre_compile.py:102(fixup)
#       828    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/enum.py:517(__new__)
#      47/8    0.000    0.000    0.002    0.000 /opt/conda/lib/python3.6/sre_compile.py:64(_compile)
#        19    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/sre_compile.py:223(_compile_charset)
#         2    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/sre_compile.py:378(<listcomp>)
#        21    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/enum.py:797(__or__)
#       393    0.001    0.000    0.001    0.000 /opt/conda/lib/python3.6/enum.py:803(__and__)
#         2    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/sre_compile.py:376(_mk_bitmap)
#        19    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/sre_compile.py:250(_optimize_charset)
#         4    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/warnings.py:428(__init__)
#         4    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/warnings.py:449(__enter__)
#         4    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/warnings.py:468(__exit__)
#         5    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/contextlib.py:79(__enter__)
#         5    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/contextlib.py:85(__exit__)
#         5    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/contextlib.py:157(helper)
#         5    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/contextlib.py:59(__init__)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/warnings.py:398(__init__)
#         1    0.000    0.000    0.001    0.001 /opt/conda/lib/python3.6/warnings.py:35(_formatwarnmsg_impl)
#         1    0.000    0.000    0.002    0.002 /opt/conda/lib/python3.6/warnings.py:85(_showwarnmsg)
#         1    0.000    0.000    0.001    0.001 /opt/conda/lib/python3.6/warnings.py:106(_formatwarnmsg)
#         1    0.000    0.000    0.002    0.002 /opt/conda/lib/python3.6/warnings.py:20(_showwarnmsg_impl)
#         2    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/warnings.py:143(simplefilter)
#         4    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/warnings.py:159(_add_filter)
#         2    0.000    0.000    0.001    0.000 /opt/conda/lib/python3.6/warnings.py:119(filterwarnings)
#         8    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/posixpath.py:232(expanduser)
#         2    0.000    0.000    0.001    0.000 /opt/conda/lib/python3.6/genericpath.py:16(exists)
#        25    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/_collections_abc.py:72(_check_methods)
#         9    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/_collections_abc.py:252(__subclasshook__)
#        14    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/_collections_abc.py:271(__subclasshook__)
#        26    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/_collections_abc.py:302(__subclasshook__)
#         2    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/_collections_abc.py:349(__subclasshook__)
#        10    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/_collections_abc.py:367(__subclasshook__)
#        63    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/_collections_abc.py:392(__subclasshook__)
#         1    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/importlib/__init__.py:108(import_module)
#         3    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/codecs.py:259(__init__)
#         3    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/codecs.py:308(__init__)
#        12    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/codecs.py:318(decode)
#       302    0.000    0.000    0.005    0.000 /opt/conda/lib/python3.6/abc.py:180(__instancecheck__)
#    304/16    0.001    0.000    0.005    0.000 /opt/conda/lib/python3.6/abc.py:196(__subclasscheck__)
#       176    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/_weakrefset.py:16(__init__)
#       176    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/_weakrefset.py:20(__enter__)
#       176    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/_weakrefset.py:26(__exit__)
#        30    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/_weakrefset.py:36(__init__)
#       176    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/_weakrefset.py:52(_commit_removals)
#       276    0.000    0.000    0.001    0.000 /opt/conda/lib/python3.6/_weakrefset.py:58(__iter__)
#       937    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/_weakrefset.py:70(__contains__)
#       183    0.000    0.000    0.000    0.000 /opt/conda/lib/python3.6/_weakrefset.py:81(add)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:430(_validate_bytecode_header)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:485(_compile_bytecode)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:524(spec_from_file_location)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:669(create_module)
#       2/1    0.000    0.000    0.002    0.002 <frozen importlib._bootstrap_external>:672(exec_module)
#         2    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:743(get_code)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:800(__init__)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:825(get_filename)
#         2    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:830(get_data)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:840(path_stats)
#        37    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1080(_path_importer_cache)
#         7    0.000    0.000    0.006    0.001 <frozen importlib._bootstrap_external>:1117(_get_spec)
#         7    0.000    0.000    0.006    0.001 <frozen importlib._bootstrap_external>:1149(find_spec)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1228(_get_spec)
#        32    0.000    0.000    0.005    0.000 <frozen importlib._bootstrap_external>:1233(find_spec)
#         2    0.000    0.000    0.003    0.001 <frozen importlib._bootstrap_external>:1281(_fill_cache)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:307(__init__)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:311(__enter__)
#         8    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:321(<genexpr>)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:318(__exit__)
#         4    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:52(_r_long)
#         7    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:369(__init__)
#         4    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:403(cached)
#         9    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:416(parent)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:424(has_location)
#       162    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:59(<listcomp>)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:504(_init_module_attrs)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:564(module_from_spec)
#       2/1    0.000    0.000    0.002    0.002 <frozen importlib._bootstrap>:651(_load_unlocked)
#         7    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:707(find_spec)
#       162    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:57(_path_join)
#         7    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:780(find_spec)
#         4    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:63(_path_split)
#        36    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:843(__enter__)
#        36    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:847(__exit__)
#        36    0.000    0.000    0.002    0.000 <frozen importlib._bootstrap_external>:75(_path_stat)
#        15    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:861(_find_spec_legacy)
#         7    0.000    0.000    0.006    0.001 <frozen importlib._bootstrap>:870(_find_spec)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:917(_sanity_check)
#       7/5    0.000    0.000    0.007    0.001 <frozen importlib._bootstrap>:936(_find_and_load_unlocked)
#       7/5    0.000    0.000    0.007    0.001 <frozen importlib._bootstrap>:966(_find_and_load)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:982(_gcd_import)
#       386    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap>:997(_handle_fromlist)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:85(_path_is_mode_type)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:94(_path_isfile)
#         4    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:263(cache_from_source)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:361(_get_cached)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:393(_check_name_wrapper)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:35(_new_module)
#         7    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:58(__init__)
#         7    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:78(acquire)
#         7    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:103(release)
#        32    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:41(_relax_case)
#         7    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:143(__init__)
#         7    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:147(__enter__)
#         7    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:151(__exit__)
#         7    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:176(cb)
#         7    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:157(_get_module_lock)
#       2/1    0.000    0.000    0.001    0.001 <frozen importlib._bootstrap>:211(_call_with_frames_removed)
#       164    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:222(_verbose_message)

# %%
def vectorize_reviews(reviews):
    vectorizer = TfidfVectorizer(stop_words = 'english', tokenizer = tokenize, \
                        min_df = 0.0025, max_df = 0.05, max_features = 1000, ngram_range = (1, 3))
    X = vectorizer.fit_transform(reviews)
    words = vectorizer.get_feature_names()
    return X, words

def print_clusters():
    num_words = 20
    X, words = vectorize_reviews(review_df['text'])
    
    kmeans = KMeans(n_clusters = 3)
    kmeans.fit(X)
    
    common_words = kmeans.cluster_centers_.argsort()[:,-1:-num_words-1:-1]
    for num, centroid in enumerate(common_words):
        print(str(num) + ' : ' + ', '.join(words[word] for word in centroid))

def calc_polarity(text):
    blob = tb.TextBlob(text)
    return blob.sentiment.polarity

def calc_subjectivity(text):
    blob = tb.TextBlob(text)
    return blob.sentiment.subjectivity

def get_pol_sub():
    review_df['polarity'] = review_df['text'].apply(calc_polarity)
    review_df['subjectivity'] = review_df['text'].apply(calc_subjectivity)
    
    print('\nMean Polarity: ' + str(review_df['polarity'].mean())\
          + '\nMean Subjectivity: ' + str(review_df['subjectivity'].mean()))

# %%
#print_clusters()
cProfile.run('print_clusters()')
#cProfile.run('get_pol_sub()')
get_pol_sub()

# %%
X
# Out:
# <453x1000 sparse matrix of type '<class 'numpy.float64'>'
# 	with 9247 stored elements in Compressed Sparse Row format>
